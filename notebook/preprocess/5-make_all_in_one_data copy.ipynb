# %%
import csv
import os
import pandas as pd
import glob

# %% [markdown]
# # make all-in-one table

# %%
tdc_paths = glob.glob('../../data/processed/tdc/*/*_date.tsv')
ml_paths = glob.glob('../../data/processed/moleculenet/moleculenet_patentdate/*/date_dataset.tsv')
ml_task_paths = glob.glob('../../data/processed/moleculenet/moleculenet_patentdate/*/tasks.txt')

# %%
print(len(tdc_paths), len(ml_paths), len(ml_task_paths))
# Out:
# 45 24 24

# %%
output_path = '../../data/processed/all_date_datasets_for_tox_benchmark.tsv'
with open(output_path, 'a', newline='') as outfile:
    writer = csv.writer(outfile, delimiter='\t')
    writer.writerow(['smiles', 'year', 'toxicity', 'dataset'])

    for path in tdc_paths:
        task_name = "tdc_" + path.split('/')[-2] + "_" + path.split('/')[-1].replace('_date.tsv', '')
        df = pd.read_csv(path, sep='\t')
        for i in range(len(df)):
            writer.writerow([df.iloc[i,0], df.iloc[i,2], df.iloc[i,1], task_name])

# %%
with open(output_path, 'a', newline='') as outfile:
    writer = csv.writer(outfile, delimiter='\t')

    for i in range(len(ml_paths)):
        task_names = []
        with open(ml_task_paths[i], 'r') as f:
            for line in f:
                task_names.append(line.strip())
        df = pd.read_csv(ml_paths[i], sep='\t', header=None)
        for j in range(len(df)):
            for k in range(len(task_names)):
                if pd.isna(df.iloc[j, k+1]):
                    continue
                task_name = "ml_" + ml_paths[i].split('/')[-2] + "_" + task_names[k]
                writer.writerow([df.iloc[j,0], df.iloc[j, 1], df.iloc[j,k+2], task_name])

# %%
df = pd.read_csv(output_path, sep='\t')

# %%
df
# Out:
#                                                      smiles      year  \
# 0           Nc1ccc(C=Cc2ccc(N)cc2S(=O)(=O)O)c(S(=O)(=O)O)c1  1973.121
# 1                                           O=C(O)c1ccccc1O  1973.063
# 2         O=[N+]([O-])c1ccc(SSc2ccc([N+](=O)[O-])cc2[N+]...  1982.145
# 3                O=[N+]([O-])c1ccccc1SSc1ccccc1[N+](=O)[O-]  1976.036
# 4                                   CC(C)(CCC(=O)O)CCC(=O)O  1979.025
# ...                                                     ...       ...
# 11255131               Cn1cnnc1SCC(=O)OCN1C(=O)c2ccccc2C1=O  2005.323
# 11255132               Cn1cnnc1SCC(=O)OCN1C(=O)c2ccccc2C1=O  2005.323
# 11255133               Cn1cnnc1SCC(=O)OCN1C(=O)c2ccccc2C1=O  2005.323
# 11255134               Cn1cnnc1SCC(=O)OCN1C(=O)c2ccccc2C1=O  2005.323
# 11255135               Cn1cnnc1SCC(=O)OCN1C(=O)c2ccccc2C1=O  2005.323
#
#           toxicity         dataset
# 0              0.0   tdc_HTS_3_HIV
# 1              0.0   tdc_HTS_3_HIV
# 2              0.0   tdc_HTS_3_HIV
# 3              0.0   tdc_HTS_3_HIV
# 4              0.0   tdc_HTS_3_HIV
# ...            ...             ...
# 11255131       0.0  ml_muv_MUV-832
# 11255132       0.0  ml_muv_MUV-846
# 11255133       0.0  ml_muv_MUV-852
# 11255134       0.0  ml_muv_MUV-858
# 11255135       0.0  ml_muv_MUV-859
#
# [11255136 rows x 4 columns]

# %% [markdown]
# # update to huggingface
# update too Large files to huggingface

# %%
from huggingface_hub import upload_file

REPO_ID="mizuno-group/patent_time_split"
output_path = '../../data/processed/all_date_datasets_for_tox_benchmark.tsv'

upload_file(
    path_or_fileobj=output_path,
    path_in_repo="all_date_datasets_for_tox_benchmark.tsv",
    repo_id=REPO_ID,
    repo_type="dataset"
)
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          | 2.09MB / 1.04GB,  803kB/s
#
#
# Processing Files (0 / 1)                :   0%|          | 4.17MB / 1.04GB, 1.30MB/s
# Processing Files (0 / 1)                :   1%|          | 12.5MB / 1.04GB, 3.68MB/s
# Processing Files (0 / 1)                :   2%|▏         | 18.8MB / 1.04GB, 5.22MB/s
# Processing Files (0 / 1)                :   3%|▎         | 27.1MB / 1.04GB, 7.14MB/s
# Processing Files (0 / 1)                :   4%|▍         | 40.2MB / 1.04GB, 10.0MB/s
# Processing Files (0 / 1)                :   5%|▌         | 56.9MB / 1.04GB, 13.5MB/s
# Processing Files (0 / 1)                :   7%|▋         | 69.4MB / 1.04GB, 15.8MB/s
# Processing Files (0 / 1)                :   7%|▋         | 72.0MB / 1.04GB, 15.7MB/s
# Processing Files (0 / 1)                :   8%|▊         | 80.2MB / 1.04GB, 16.7MB/s
# Processing Files (0 / 1)                :   9%|▉         | 93.4MB / 1.04GB, 18.7MB/s
# Processing Files (0 / 1)                :   9%|▉         | 96.0MB / 1.04GB, 18.5MB/s
# Processing Files (0 / 1)                :  10%|█         |  109MB / 1.04GB, 20.2MB/s
# Processing Files (0 / 1)                :  14%|█▍        |  147MB / 1.04GB, 26.2MB/s
# Processing Files (0 / 1)                :  18%|█▊        |  184MB / 1.04GB, 31.7MB/s
# Processing Files (0 / 1)                :  19%|█▉        |  203MB / 1.04GB, 33.8MB/s
# Processing Files (0 / 1)                :  23%|██▎       |  236MB / 1.04GB, 38.1MB/s
# Processing Files (0 / 1)                :  24%|██▍       |  255MB / 1.04GB, 39.8MB/s
# Processing Files (0 / 1)                :  26%|██▌       |  268MB / 1.04GB, 40.6MB/s
# Processing Files (0 / 1)                :  26%|██▌       |  271MB / 1.04GB, 39.8MB/s
# Processing Files (0 / 1)                :  26%|██▌       |  271MB / 1.04GB, 38.7MB/s
# Processing Files (0 / 1)                :  26%|██▋       |  274MB / 1.04GB, 38.0MB/s
# Processing Files (0 / 1)                :  27%|██▋       |  276MB / 1.04GB, 37.3MB/s
# Processing Files (0 / 1)                :  30%|██▉       |  312MB / 1.04GB, 41.0MB/s
# Processing Files (0 / 1)                :  31%|███       |  320MB / 1.04GB, 41.0MB/s
# Processing Files (0 / 1)                :  33%|███▎      |  347MB / 1.04GB, 43.4MB/s
# Processing Files (0 / 1)                :  36%|███▋      |  380MB / 1.04GB, 46.3MB/s
# Processing Files (0 / 1)                :  38%|███▊      |  396MB / 1.04GB, 47.2MB/s
# Processing Files (0 / 1)                :  40%|████      |  418MB / 1.04GB, 48.6MB/s
# Processing Files (0 / 1)                :  40%|████      |  419MB / 1.04GB, 47.6MB/s
# Processing Files (0 / 1)                :  41%|████      |  430MB / 1.04GB, 47.7MB/s
# Processing Files (0 / 1)                :  43%|████▎     |  443MB / 1.04GB, 48.2MB/s
# Processing Files (0 / 1)                :  46%|████▌     |  481MB / 1.04GB, 51.2MB/s
# Processing Files (0 / 1)                :  48%|████▊     |  498MB / 1.04GB, 51.8MB/s
# Processing Files (0 / 1)                :  49%|████▉     |  514MB / 1.04GB, 52.5MB/s
# Processing Files (0 / 1)                :  51%|█████▏    |  535MB / 1.04GB, 53.5MB/s
# Processing Files (0 / 1)                :  53%|█████▎    |  554MB / 1.04GB, 54.3MB/s
# Processing Files (0 / 1)                :  55%|█████▍    |  571MB / 1.04GB, 55.9MB/s
# Processing Files (0 / 1)                :  57%|█████▋    |  593MB / 1.04GB, 58.2MB/s
# Processing Files (0 / 1)                :  58%|█████▊    |  602MB / 1.04GB, 59.0MB/s
#
# Processing Files (0 / 1)                :  58%|█████▊    |  604MB / 1.04GB, 59.2MB/s
# Processing Files (0 / 1)                :  60%|█████▉    |  622MB / 1.04GB, 61.4MB/s
# Processing Files (0 / 1)                :  61%|██████▏   |  641MB / 1.04GB, 62.8MB/s
# Processing Files (0 / 1)                :  63%|██████▎   |  657MB / 1.04GB, 64.4MB/s
# Processing Files (0 / 1)                :  64%|██████▍   |  670MB / 1.04GB, 65.7MB/s
#
# Processing Files (0 / 1)                :  64%|██████▍   |  671MB / 1.04GB, 65.8MB/s
#
# Processing Files (0 / 1)                :  67%|██████▋   |  703MB / 1.04GB, 68.7MB/s
# Processing Files (0 / 1)                :  69%|██████▊   |  716MB / 1.04GB, 70.0MB/s
#
# Processing Files (0 / 1)                :  70%|███████   |  735MB / 1.04GB, 71.6MB/s
#
#
#
#
# Processing Files (0 / 1)                :  71%|███████   |  738MB / 1.04GB, 66.7MB/s
#
# Processing Files (0 / 1)                :  74%|███████▍  |  772MB / 1.04GB, 68.6MB/s
#
#
# Processing Files (0 / 1)                :  75%|███████▌  |  787MB / 1.04GB, 67.7MB/s
# Processing Files (0 / 1)                :  77%|███████▋  |  801MB / 1.04GB, 67.8MB/s
#
# Processing Files (0 / 1)                :  77%|███████▋  |  805MB / 1.04GB, 60.9MB/s
#
#
#
#
# Processing Files (0 / 1)                :  81%|████████  |  844MB / 1.04GB, 56.3MB/s
#
#
# Processing Files (0 / 1)                :  83%|████████▎ |  861MB / 1.04GB, 57.4MB/s
# Processing Files (0 / 1)                :  83%|████████▎ |  867MB / 1.04GB, 54.4MB/s
#
# Processing Files (0 / 1)                :  84%|████████▎ |  872MB / 1.04GB, 51.4MB/s
#
#
#
# Processing Files (0 / 1)                :  88%|████████▊ |  914MB / 1.04GB, 48.2MB/s
#
#
# Processing Files (0 / 1)                :  90%|█████████ |  939MB / 1.04GB, 44.9MB/s
#
# Processing Files (0 / 1)                :  90%|█████████ |  939MB / 1.04GB, 41.6MB/s
#
# Processing Files (0 / 1)                :  94%|█████████▍|  983MB / 1.04GB, 42.0MB/s
#
# Processing Files (0 / 1)                :  96%|█████████▌| 1.00GB / 1.04GB, 40.0MB/s
# Processing Files (0 / 1)                :  98%|█████████▊| 1.02GB / 1.04GB, 41.0MB/s
#
# Processing Files (0 / 1)                :  98%|█████████▊| 1.02GB / 1.04GB, 41.3MB/s
#
#
#
# Processing Files (0 / 1)                :  99%|█████████▉| 1.03GB / 1.04GB, 35.5MB/s
# Processing Files (0 / 1)                : 100%|█████████▉| 1.04GB / 1.04GB, 36.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████| 1.04GB / 1.04GB, 33.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████| 1.04GB / 1.04GB, 30.8MB/s
# New Data Upload                         : 100%|██████████| 1.04GB / 1.04GB, 30.8MB/s
#   ...date_datasets_for_tox_benchmark.tsv: 100%|██████████| 1.04GB / 1.04GB
# CommitInfo(commit_url='https://huggingface.co/datasets/mizuno-group/patent_time_split/commit/71f04736ef4b713b30be050e4a0df20c4dcdd12d', commit_message='Upload all_date_datasets_for_tox_benchmark.tsv with huggingface_hub', commit_description='', oid='71f04736ef4b713b30be050e4a0df20c4dcdd12d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/mizuno-group/patent_time_split', endpoint='https://huggingface.co', repo_type='dataset', repo_id='mizuno-group/patent_time_split'), pr_revision=None, pr_num=None)
